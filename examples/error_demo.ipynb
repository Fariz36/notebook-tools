# %% [markdown]
# # Error Triage Demo
#
# This notebook intentionally contains errors for testing the `error-triage` skill.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({
    "x": np.arange(50),
    "y": np.random.randn(50)
})
print(f"DataFrame created with {len(df)} rows")
# Out:
# DataFrame created with 50 rows

# %%
df["z"] = df["x"] * df["y"]
print(df.head())
# Out:
# KeyError: "Column 'z' not found in DataFrame"

# %%
result = 10 + "hello"
print(result)
# Out:
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# ## Fixed Section
#
# This cell works correctly.

# %%
df.head(3)
# Out:
#     x         y
# 0   0  0.496714
# 1   1 -0.138264
# 2   2  0.647689
